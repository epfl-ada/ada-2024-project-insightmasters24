# %%
import sys
sys.path.append("..")

from src.models.ridge import ridge_regression_characters, plot_important_features
from src.data.dataloader import DataLoader
from src.utils.data_utils import preprocess_data_for_model

# %%
dataloader = DataLoader()
characters = dataloader.load_characters()
movies_with_characters = dataloader.load_movies_with_characters()
df = preprocess_data_for_model(movies_with_characters)
# Out:
# c:\Users\amene\Desktop\adap\ada-2024-project-insightmasters24\tests\..\src\data\dataloader.py:172: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmdb_df = pd.read_csv(self.paths["tmdb_movies"])
# c:\Users\amene\Desktop\adap\ada-2024-project-insightmasters24\tests\..\src\data\dataloader.py:172: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmdb_df = pd.read_csv(self.paths["tmdb_movies"])
# c:\Users\amene\Desktop\adap\ada-2024-project-insightmasters24\tests\..\src\data\dataloader.py:172: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmdb_df = pd.read_csv(self.paths["tmdb_movies"])

# %%
ft_matrix = ridge_regression_characters(df, show_details=True)
# Out:
# 1985-1989
#
# Model Statistics:
# R-squared: 0.11395963162869283
#
# Feature Coefficients and P-values:
#                      Feature   Coefficient   P-value
# 36      Oceanian Ethnicities  3.779257e+07  0.002137
# 5   actor_age_at_release_max  3.729827e+07  0.006121
# 1990-1994
#
# Model Statistics:
# R-squared: 0.2034832705264915
#
# Feature Coefficients and P-values:
#                          Feature   Coefficient   P-value
# 10                     Adventure  7.079463e+07  0.000095
# 1                 actor_gender_F  6.301556e+07  0.010789
# 13             Crime and Mystery  6.257953e+07  0.001227
# 19   Fantasy and Science Fiction  6.254746e+07  0.001832
# 21        LGBT and Gender Issues  6.106801e+07  0.001362
# 11                     Animation  5.987926e+07  0.009638
# 25             War and Political  5.865684e+07  0.012166
# 27           African Ethnicities  5.829185e+07  0.027835
# 22            Musicals and Dance  5.683481e+07  0.048270
# 29             Asian Ethnicities  5.673367e+07  0.042041
# 17  Experimental and Independent  4.135965e+07  0.025363
# 4       actor_age_at_release_min  4.040523e+07  0.018269
# 1995-1999
#
# Model Statistics:
# R-squared: 0.2167202803659023
#
# Feature Coefficients and P-values:
#                           Feature   Coefficient   P-value
# 9                          Action  7.718142e+07  0.001777
# 26                                 7.308013e+07  0.003325
# 19    Fantasy and Science Fiction  7.266580e+07  0.001738
# 23                        Romance  7.238977e+07  0.005399
# 10                      Adventure  7.178526e+07  0.027585
# 28           American Ethnicities  7.164317e+07  0.012056
# 11                      Animation  7.001286e+07  0.019370
# 29              Asian Ethnicities  6.871148e+07  0.014975
# 38   Western European Ethnicities  6.837754e+07  0.025683
# 5        actor_age_at_release_max  6.810457e+07  0.029595
# 32             Jewish Communities  6.793522e+07  0.034618
# 37  Southern European Ethnicities  6.759164e+07  0.043580
# 3                         F ratio  4.948931e+07  0.028763
# 4        actor_age_at_release_min  4.847567e+07  0.007202
# 17   Experimental and Independent  4.792876e+07  0.004092
# 6         actor_height_meters_min  4.530374e+07  0.000549
# 2000-2004
#
# Model Statistics:
# R-squared: 0.3116733739753086
#
# Feature Coefficients and P-values:
#                           Feature   Coefficient       P-value
# 36           Oceanian Ethnicities  1.042784e+08  4.920495e-10
# 19    Fantasy and Science Fiction  1.039360e+08  2.301890e-08
# 10                      Adventure  9.814714e+07  3.149231e-03
# 5        actor_age_at_release_max  9.734512e+07  1.205993e-05
# 30   Eastern European Ethnicities  9.131900e+07  1.731236e-03
# 35  Northern European Ethnicities  9.042962e+07  3.242319e-03
# 31             Indigenous Peoples  8.950069e+07  7.988808e-03
# 4        actor_age_at_release_min  6.576203e+07  1.549873e-03
# 17   Experimental and Independent  6.508471e+07  8.059303e-04
# 6         actor_height_meters_min  6.135579e+07  3.407120e-05
# 2005-2009
#
# Model Statistics:
# R-squared: 0.2564601115509758
#
# Feature Coefficients and P-values:
#                           Feature   Coefficient   P-value
# 19    Fantasy and Science Fiction  1.027262e+08  0.000004
# 11                      Animation  9.796048e+07  0.000326
# 38   Western European Ethnicities  9.639418e+07  0.000298
# 2                  actor_gender_M  9.480260e+07  0.037116
# 9                          Action  9.479233e+07  0.010689
# 10                      Adventure  9.476500e+07  0.013518
# 23                        Romance  9.361942e+07  0.006402
# 37  Southern European Ethnicities  9.279824e+07  0.002720
# 7         actor_height_meters_max  9.097713e+07  0.015166
# 29              Asian Ethnicities  9.048595e+07  0.011232
# 32             Jewish Communities  8.871173e+07  0.042095
# 31             Indigenous Peoples  8.824895e+07  0.042080
# 36           Oceanian Ethnicities  8.809832e+07  0.047367
# 17   Experimental and Independent  6.848092e+07  0.018724
# 6         actor_height_meters_min  5.579112e+07  0.000001
# 2010-2014
#
# Model Statistics:
# R-squared: 0.40960936745681464
#
# Feature Coefficients and P-values:
#                           Feature   Coefficient       P-value
# 19    Fantasy and Science Fiction  1.493898e+08  3.108732e-07
# 37  Southern European Ethnicities  1.486085e+08  6.276095e-08
# 10                      Adventure  1.480521e+08  5.322853e-05
# 29              Asian Ethnicities  1.393985e+08  1.007098e-05
# 11                      Animation  1.290943e+08  1.928009e-02
# 30   Eastern European Ethnicities  1.270811e+08  7.670920e-03
# 32             Jewish Communities  1.265527e+08  1.577957e-02
# 38   Western European Ethnicities  1.265462e+08  1.324877e-02
# 17   Experimental and Independent  9.016521e+07  1.568521e-02
# 28           American Ethnicities  8.704614e+07  3.220355e-02
# Number of movies in each period:
# period
# 1985-1989     749
# 1990-1994     789
# 1995-1999     986
# 2000-2004    1005
# 2005-2009    1279
# 2010-2014     583
# Name: count, dtype: int64

# %%
plot_important_features(ft_matrix)
