# %%
import sys
sys.path.append("..")

from src.models.ridge import ridge_regression1, plot_most_important_features_generated_by_ridge_regression
from src.data.dataloader import DataLoader
from src.utils.data_utils import preprocess_data_for_model

# %%
dataloader = DataLoader()
characters = dataloader.load_characters()
movies_with_characters = dataloader.load_movies_with_characters()
df = preprocess_data_for_model(movies_with_characters)
# Out:
# c:\Users\amene\Desktop\adap\ada-2024-project-insightmasters24\tests\..\src\data\dataloader.py:172: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmdb_df = pd.read_csv(self.paths["tmdb_movies"])
# c:\Users\amene\Desktop\adap\ada-2024-project-insightmasters24\tests\..\src\data\dataloader.py:172: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmdb_df = pd.read_csv(self.paths["tmdb_movies"])
# c:\Users\amene\Desktop\adap\ada-2024-project-insightmasters24\tests\..\src\data\dataloader.py:172: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   tmdb_df = pd.read_csv(self.paths["tmdb_movies"])

# %%
ft_matrix = ridge_regression1(df, show_details=True)
# Out:
# 1985-1989
#
# Model Statistics:
# R-squared: 0.07938802513383081
#
# Feature Coefficients and P-values:
#                          Feature   Coefficient   P-value
# 6       actor_age_at_release_max  3.653982e+07  0.014614
# 18  Experimental and Independent  2.573737e+07  0.035222
# 1990-1994
#
# Model Statistics:
# R-squared: 0.18436982362996868
#
# Feature Coefficients and P-values:
#                          Feature   Coefficient   P-value
# 11                     Adventure  7.126834e+07  0.000065
# 2                 actor_gender_F  6.505234e+07  0.003813
# 20   Fantasy and Science Fiction  6.244487e+07  0.001882
# 14             Crime and Mystery  6.222403e+07  0.001511
# 22        LGBT and Gender Issues  6.077241e+07  0.001759
# 26             War and Political  6.025955e+07  0.002983
# 12                     Animation  5.893828e+07  0.018645
# 18  Experimental and Independent  4.203349e+07  0.039635
# 5       actor_age_at_release_min  4.084583e+07  0.023832
# 1995-1999
#
# ...

# %%
plot_most_important_features_generated_by_ridge_regression(ft_matrix)
