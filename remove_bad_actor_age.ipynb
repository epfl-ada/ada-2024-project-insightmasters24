# %%
import pandas as pd

from src.data.dataloader import DataLoader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataloader = DataLoader()

# %%
characters = dataloader.load_characters()
print(len(characters))
characters.head()
# Out:
# 450787
#    wikipedia_movie_id wikidata_movie_id              character_name  \
# 0              975900           Q261700                    Akooshay
# 1              975900           Q261700  Lieutenant Melanie Ballard
# 2              975900           Q261700         Desolation Williams
# 3              975900           Q261700          Sgt Jericho Butler
# 4              975900           Q261700             Bashira Kincaid
#
#   actor_date_of_birth actor_gender  actor_height_meters          actor_name  \
# 0          1958-08-26            F                1.620      Wanda De Jesus
# 1          1974-08-15            F                1.780  Natasha Henstridge
# 2          1969-06-15            M                1.727            Ice Cube
# 3          1967-09-12            M                1.750       Jason Statham
# 4          1977-09-25            F                1.650         Clea DuVall
#
#    actor_age_at_release          ethnicity wikidata_character_id  \
# 0                  42.0                NaN                   NaN
# 1                  27.0                NaN                   NaN
# 2                  32.0  African Americans                   NaN
# 3                  33.0                NaN                   NaN
# 4                  23.0                NaN                   NaN
#
#   wikidata_actor_id
# 0          Q1873468
# 1           Q230527
# 2           Q173637
# 3           Q169963
# 4           Q233347

# %%
# Merge characters with movies to get release dates
characters_with_movies = pd.merge(
    characters,
    dataloader.load_movies()[["wikipedia_movie_id", "Movie release date"]],
    on="wikipedia_movie_id",
)


# Extract first 4 characters (year) from birth date and convert to numeric
characters_with_movies["actor_birth_year"] = pd.to_numeric(
    characters_with_movies["actor_date_of_birth"].str[:4], errors="coerce"
)

# Extract movie year from release date
characters_with_movies["movie_release_year"] = pd.to_numeric(
    characters_with_movies["Movie release date"].str[:4], errors="coerce"
)

characters_with_movies.drop(columns=["Movie release date"], inplace=True)

print(len(characters_with_movies))
# Out:
# 450787

# %%
characters_with_movies[characters_with_movies["actor_birth_year"].isna()].head()
# Out:
#     wikipedia_movie_id wikidata_movie_id  character_name actor_date_of_birth  \
# 7               975900           Q261700  Big Daddy Mars                 NaN
# 9               975900           Q261700             Uno                 NaN
# 10              975900           Q261700             Dos                 NaN
# 13              975900           Q261700       Zimmerman                 NaN
# 17             3196793               NaN  Police Officer                 NaN
#
#    actor_gender  actor_height_meters       actor_name  actor_age_at_release  \
# 7             M                  NaN  Richard Cetrone                   NaN
# 9             M                  NaN      Duane Davis                   NaN
# 10            M                  NaN   Lobo Sebastian                   NaN
# 13            M                  NaN   Rick Edelstein                   NaN
# 17            M                  NaN     Allen Cutler                   NaN
#
#    ethnicity wikidata_character_id wikidata_actor_id  actor_birth_year  \
# 7        NaN                   NaN               NaN               NaN
# 9        NaN                   NaN               NaN               NaN
# 10       NaN                   NaN               NaN               NaN
# 13       NaN                   NaN               NaN               NaN
# 17       NaN                   NaN               NaN               NaN
#
#     movie_release_year
# 7               2001.0
# 9               2001.0
# 10              2001.0
# 13              2001.0
# 17              2000.0

# %%
# Filter out invalid years (before 1800 and after 2014)
characters_with_movies = characters_with_movies[
    (characters_with_movies["actor_birth_year"].isna())
    | (
        (characters_with_movies["actor_birth_year"] > 1800)
        & (characters_with_movies["actor_birth_year"] < 2014)
    )
]

# %%
characters_with_movies[characters_with_movies["actor_birth_year"].isna()].head()
# Out:
#     wikipedia_movie_id wikidata_movie_id  character_name actor_date_of_birth  \
# 7               975900           Q261700  Big Daddy Mars                 NaN
# 9               975900           Q261700             Uno                 NaN
# 10              975900           Q261700             Dos                 NaN
# 13              975900           Q261700       Zimmerman                 NaN
# 17             3196793               NaN  Police Officer                 NaN
#
#    actor_gender  actor_height_meters       actor_name  actor_age_at_release  \
# 7             M                  NaN  Richard Cetrone                   NaN
# 9             M                  NaN      Duane Davis                   NaN
# 10            M                  NaN   Lobo Sebastian                   NaN
# 13            M                  NaN   Rick Edelstein                   NaN
# 17            M                  NaN     Allen Cutler                   NaN
#
#    ethnicity wikidata_character_id wikidata_actor_id  actor_birth_year  \
# 7        NaN                   NaN               NaN               NaN
# 9        NaN                   NaN               NaN               NaN
# 10       NaN                   NaN               NaN               NaN
# 13       NaN                   NaN               NaN               NaN
# 17       NaN                   NaN               NaN               NaN
#
#     movie_release_year
# 7               2001.0
# 9               2001.0
# 10              2001.0
# 13              2001.0
# 17              2000.0

# %%
print("Characters with movies after filtering:", len(characters_with_movies))
characters_with_movies.head()
# Out:
# Characters with movies after filtering: 450762
#    wikipedia_movie_id wikidata_movie_id              character_name  \
# 0              975900           Q261700                    Akooshay
# 1              975900           Q261700  Lieutenant Melanie Ballard
# 2              975900           Q261700         Desolation Williams
# 3              975900           Q261700          Sgt Jericho Butler
# 4              975900           Q261700             Bashira Kincaid
#
#   actor_date_of_birth actor_gender  actor_height_meters          actor_name  \
# 0          1958-08-26            F                1.620      Wanda De Jesus
# 1          1974-08-15            F                1.780  Natasha Henstridge
# 2          1969-06-15            M                1.727            Ice Cube
# 3          1967-09-12            M                1.750       Jason Statham
# 4          1977-09-25            F                1.650         Clea DuVall
#
#    actor_age_at_release          ethnicity wikidata_character_id  \
# 0                  42.0                NaN                   NaN
# 1                  27.0                NaN                   NaN
# 2                  32.0  African Americans                   NaN
# 3                  33.0                NaN                   NaN
# 4                  23.0                NaN                   NaN
#
#   wikidata_actor_id  actor_birth_year  movie_release_year
# 0          Q1873468            1958.0              2001.0
# 1           Q230527            1974.0              2001.0
# 2           Q173637            1969.0              2001.0
# 3           Q169963            1967.0              2001.0
# 4           Q233347            1977.0              2001.0

# %%
# Calculate age at release
characters_with_movies["actor_age_at_release"] = (
    characters_with_movies["movie_release_year"]
    - characters_with_movies["actor_birth_year"]
)

# Update the characters DataFrame
# characters = characters_with_movies.drop(["Movie release date", "birth_year"], axis=1)
print(len(characters_with_movies))
characters_with_movies.sort_values("actor_age_at_release").head()
# Out:
# 450762
#         wikipedia_movie_id wikidata_movie_id character_name  \
# 383908             4210812          Q3794530         Glinda
# 298017             6149842          Q2456767     Jack's pal
# 30168             33625136               NaN            NaN
# 92533             17455134          Q3840588     Sua moglie
# 387597            20859086               NaN            NaN
#
#        actor_date_of_birth actor_gender  actor_height_meters  \
# 383908          1992-02-17            M                  NaN
# 298017          1988-05-23            M                  NaN
# 30168           1981-10-04            F                  NaN
# 92533           1978-04-14            F                  NaN
# 387597          1973-08-24            F                  NaN
#
#                   actor_name  actor_age_at_release ethnicity  \
# 383908             Olive Cox                 -82.0       NaN
# 298017       William R. Dunn                 -76.0       NaN
# 30168   Muriel Martin-Harvey                 -65.0       NaN
# 92533            Tilde Teldi                 -64.0       NaN
# 387597          Grey DeLisle                 -61.0       NaN
#
#        wikidata_character_id wikidata_actor_id  actor_birth_year  \
# 383908              Q2292767               NaN            1992.0
# 298017                   NaN               NaN            1988.0
# 30168                    NaN               NaN            1981.0
# 92533                    NaN               NaN            1978.0
# 387597                   NaN            Q13938            1973.0
#
#         movie_release_year
# 383908              1910.0
# 298017              1912.0
# 30168               1916.0
# 92533               1914.0
# 387597              1912.0

# %%
# Keep only actors with age at release > 0
characters_with_movies = characters_with_movies[
    (characters_with_movies["actor_age_at_release"].isna())
    | (characters_with_movies["actor_age_at_release"] > 0)
]

print("Characters with movies after filtering:", len(characters_with_movies))
characters_with_movies.head()
# Out:
# Characters with movies after filtering: 450329
#    wikipedia_movie_id wikidata_movie_id              character_name  \
# 0              975900           Q261700                    Akooshay
# 1              975900           Q261700  Lieutenant Melanie Ballard
# 2              975900           Q261700         Desolation Williams
# 3              975900           Q261700          Sgt Jericho Butler
# 4              975900           Q261700             Bashira Kincaid
#
#   actor_date_of_birth actor_gender  actor_height_meters          actor_name  \
# 0          1958-08-26            F                1.620      Wanda De Jesus
# 1          1974-08-15            F                1.780  Natasha Henstridge
# 2          1969-06-15            M                1.727            Ice Cube
# 3          1967-09-12            M                1.750       Jason Statham
# 4          1977-09-25            F                1.650         Clea DuVall
#
#    actor_age_at_release          ethnicity wikidata_character_id  \
# 0                  43.0                NaN                   NaN
# 1                  27.0                NaN                   NaN
# 2                  32.0  African Americans                   NaN
# 3                  34.0                NaN                   NaN
# 4                  24.0                NaN                   NaN
#
#   wikidata_actor_id  actor_birth_year  movie_release_year
# 0          Q1873468            1958.0              2001.0
# 1           Q230527            1974.0              2001.0
# 2           Q173637            1969.0              2001.0
# 3           Q169963            1967.0              2001.0
# 4           Q233347            1977.0              2001.0

# %%
test = characters_with_movies[characters_with_movies["actor_age_at_release"].isna()]

test.head()
# Out:
#     wikipedia_movie_id wikidata_movie_id  character_name actor_date_of_birth  \
# 7               975900           Q261700  Big Daddy Mars                 NaN
# 9               975900           Q261700             Uno                 NaN
# 10              975900           Q261700             Dos                 NaN
# 13              975900           Q261700       Zimmerman                 NaN
# 17             3196793               NaN  Police Officer                 NaN
#
#    actor_gender  actor_height_meters       actor_name  actor_age_at_release  \
# 7             M                  NaN  Richard Cetrone                   NaN
# 9             M                  NaN      Duane Davis                   NaN
# 10            M                  NaN   Lobo Sebastian                   NaN
# 13            M                  NaN   Rick Edelstein                   NaN
# 17            M                  NaN     Allen Cutler                   NaN
#
#    ethnicity wikidata_character_id wikidata_actor_id  actor_birth_year  \
# 7        NaN                   NaN               NaN               NaN
# 9        NaN                   NaN               NaN               NaN
# 10       NaN                   NaN               NaN               NaN
# 13       NaN                   NaN               NaN               NaN
# 17       NaN                   NaN               NaN               NaN
#
#     movie_release_year
# 7               2001.0
# 9               2001.0
# 10              2001.0
# 13              2001.0
# 17              2000.0

# %%
len(characters_with_movies)
# Out:
# 450329
